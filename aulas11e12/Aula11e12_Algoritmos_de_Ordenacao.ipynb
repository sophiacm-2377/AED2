# %% [markdown]
# ![Algoritmos e Estrutura de Dados II - Prof Piva](AED2_banner.jpg)

# %% [markdown]
# ## Aulas 11 e 12 -  Algoritmos de ordenação

# %% [markdown]
# ![Comparação de Algoritmos de Ordenação](algoritmos.png)

# %% [markdown]
# ## Bubble sort  ( O(n**2) )

# %%
import numpy as np

# %%
def bubble_sort(vetor):
  n = len(vetor)

  for i in range(n):
    for j in range(0, n - i - 1):
      if vetor[j] > vetor[j + 1]:
        vetor[j], vetor[j + 1] = vetor[j+1], vetor[j]
          
  return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))
vetor = vet

# %%
# Vetor não ordenado
print(vet)
# Out:
# [np.int32(637), np.int32(231), np.int32(283), np.int32(616), np.int32(230), np.int32(581), np.int32(257), np.int32(78), np.int32(79), np.int32(268), np.int32(660), np.int32(119), np.int32(405), np.int32(267), np.int32(100), np.int32(315), np.int32(897), np.int32(728), np.int32(671), np.int32(181), np.int32(502), np.int32(895), np.int32(987), np.int32(696), np.int32(458), np.int32(893), np.int32(331), np.int32(567), np.int32(663), np.int32(146), np.int32(886), np.int32(226), np.int32(796), np.int32(844), np.int32(890), np.int32(850), np.int32(859), np.int32(548), np.int32(64), np.int32(733), np.int32(698), np.int32(508), np.int32(239), np.int32(990), np.int32(696), np.int32(132), np.int32(869), np.int32(444), np.int32(41), np.int32(18), np.int32(577), np.int32(539), np.int32(535), np.int32(379), np.int32(912), np.int32(99), np.int32(215), np.int32(107), np.int32(305), np.int32(753), np.int32(362), np.int32(187), np.int32(371), np.int32(520), np.int32(794), np.int32(18), np.int32(241), np.int32(703), np.int32(74), np.int32(970), np.int32(529), np.int32(468), np.int32(898), np.int32(470), np.int32(569), np.int32(688), np.int32(936), np.int32(609), np.int32(403), np.int32(172), np.int32(98), np.int32(911), np.int32(246), np.int32(204), np.int32(816), np.int32(165), np.int32(957), np.int32(612), np.int32(793), np.int32(190), np.int32(365), np.int32(737), np.int32(173), np.int32(563), np.int32(306), np.int32(125), np.int32(587), np.int32(225), np.int32(455), np.int32(499), np.int32(579), np.int32(49), np.int32(485), np.int32(825), np.int32(831), np.int32(849), np.int32(918), np.int32(6), np.int32(683), np.int32(383), np.int32(927), np.int32(986), np.int32(400), np.int32(921), np.int32(643), np.int32(822), np.int32(793), np.int32(704), np.int32(115), np.int32(103), np.int32(869), np.int32(540), np.int32(276), np.int32(336), np.int32(814), np.int32(237), np.int32(662), np.int32(158), np.int32(887), np.int32(160), np.int32(986), np.int32(919), np.int32(243), np.int32(416), np.int32(94), np.int32(12), np.int32(546), np.int32(632), np.int32(974), np.int32(580), np.int32(92), np.int32(766), np.int32(650), np.int32(612), np.int32(411), np.int32(465), np.int32(639), np.int32(6), np.int32(416), np.int32(244), np.int32(305), np.int32(373), np.int32(500), np.int32(545), np.int32(24), np.int32(580), np.int32(408), np.int32(961), np.int32(307), np.int32(262), np.int32(737), np.int32(64), np.int32(16), np.int32(637), np.int32(135), np.int32(950), np.int32(700), np.int32(550), np.int32(231), np.int32(965), np.int32(721), np.int32(808), np.int32(243), np.int32(979), np.int32(5), np.int32(695), np.int32(410), np.int32(516), np.int32(535), np.int32(876), np.int32(184), np.int32(897), np.int32(708), np.int32(925), np.int32(278), np.int32(792), np.int32(437), np
(612), np.int32(411), np.int32(465), np.int32(639), np.int32(6), np.int32(416), np.int32(244), np.int32(305), np.int32(373), np.int32(500), np.int32(545), np.int32(24), np.int32(580), np.int32(408), np.int32(961), np.int32(307), np.int32(262), np.int32(737), np.int32(64), np.int32(16), np.int32(637), np.int32(135), np.int32(950), np.int32(700), np.int32(550), np.int32(231), np.int32(965), np.int32(721), np.int32(808), np.int32(243), np.int32(979), np.int32(5), np.int32(695), np.int32(410), np.int32(516), np.int32(535), np.int32(876), np.int32(184), np.int32(897), np.int32(708), np.int32(925), np.int32(278), np.int32(792), np.int32(437), np.int32(958), np.int32(312), np.int32(350), np.int32(704), np.int32(26), np.int32(892), np.int32(295), np.int32(415), np.int32(380), np.int32(790), np.int32(638), np.int32(891), np.int32(335), np.int32(462), np.int32(751), np.int32(941), np.int32(450), np.int32(226), np.int32(258), np.int32(865), np.int32(621), np.int32(109), np.int32(256), np.int32(901), np.int32(472), np.int32(553), np.int32(787), np.int32(121), np.int32(902), np.int32(4), np.int32(464), np.int32(450), np.int32(390), np.int32(471), np.int32(878), np.int32(329), np.int32(604), np.int32(198), np.int32(32), np.int32(533), np.int32(992), np.int32(296), np.int32(992), np.int32(476), np.int32(408), np.int32(569), np.int32(470), np.int32(131), np.int32(356), np.int32(678), np.int32(775), np.int32(305), np.int32(567), np.int32(918), np.int32(889), np.int32(670), np.int32(62), np.int32(609), np.int32(525), np.int32(49), np.int32(274), np.int32(638), np.int32(197), np.int32(207), np.int32(791), np.int32(547), np.int32(895), np.int32(968), np.int32(578), np.int32(637), np.int32(239), np.int32(301), np.int32(105), np.int32(199), np.int32(545), np.int32(824), np.int32(641), np.int32(595), np.int32(332), np.int32(413), np.int32(438), np.int3 ...

# %% [markdown]
# ## Selection sort    ( O(n**2) )

# %%
def selection_sort(vetor):
  n = len(vetor)

  for i in range(n):
    id_minimo = i
    for j in range(i + 1, n):
      if vetor[id_minimo] > vetor[j]:
        id_minimo = j
    temp = vetor[i]
    vetor[i] = vetor[id_minimo]
    vetor[id_minimo] = temp

  return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit selection_sort(vet)
# Out:
# 1.49 s ± 33.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Vetor ordenado
print(vet)
# Out:
# [np.int32(0), np.int32(0), np.int32(0), np.int32(0), np.int32(0), np.int32(0), np.int32(0), np.int32(1), np.int32(1), np.int32(2), np.int32(2), np.int32(2), np.int32(2), np.int32(3), np.int32(3), np.int32(3), np.int32(3), np.int32(3), np.int32(4), np.int32(4), np.int32(4), np.int32(5), np.int32(5), np.int32(5), np.int32(5), np.int32(5), np.int32(6), np.int32(6), np.int32(7), np.int32(7), np.int32(7), np.int32(7), np.int32(7), np.int32(7), np.int32(7), np.int32(8), np.int32(8), np.int32(9), np.int32(9), np.int32(10), np.int32(10), np.int32(11), np.int32(11), np.int32(11), np.int32(11), np.int32(12), np.int32(12), np.int32(12), np.int32(12), np.int32(12), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(14), np.int32(14), np.int32(14), np.int32(14), np.int32(14), np.int32(15), np.int32(15), np.int32(15), np.int32(16), np.int32(16), np.int32(16), np.int32(17), np.int32(17), np.int32(17), np.int32(17), np.int32(17), np.int32(17), np.int32(17), np.int32(17), np.int32(17), np.int32(17), np.int32(17), np.int32(18), np.int32(18), np.int32(18), np.int32(18), np.int32(18), np.int32(19), np.int32(19), np.int32(20), np.int32(20), np.int32(20), np.int32(20), np.int32(21), np.int32(21), np.int32(22), np.int32(22), np.int32(22), np.int32(22), np.int32(23), np.int32(23), np.int32(23), np.int32(23), np.int32(24), np.int32(24), np.int32(24), np.int32(24), np.int32(24), np.int32(24), np.int32(24), np.int32(25), np.int32(25), np.int32(25), np.int32(25), np.int32(25), np.int32(25), np.int32(25), np.int32(25), np.int32(26), np.int32(26), np.int32(26), np.int32(26), np.int32(27), np.int32(27), np.int32(27), np.int32(27), np.int32(28), np.int32(28), np.int32(28), np.int32(29), np.int32(29), np.int32(29), np.int32(29), np.int32(29), np.int32(29), np.int32(30), np.int32(30), np.int32(30), np.int32(30), np.int32(30), np.int32(31), np.int32(31), np.int32(31), np.int32(31), np.int32(31), np.int32(31), np.int32(31), np.int32(32), np.int32(32), np.int32(32), np.int32(32), np.int32(32), np.int32(32), np.int32(32), np.int32(32), np.int32(33), np.int32(33), np.int32(33), np.int32(33), np.int32(33), np.int32(33), np.int32(33), np.int32(34), np.int32(34), np.int32(35), np.int32(35), np.int32(35), np.int32(35), np.int32(35), np.int32(35), np.int32(36), np.int32(36), np.int32(36), np.int32(36), np.int32(37), np.int32(37), np.int32(37), np.int32(37), np.int32(37), np.int32(37), np.int32(37), np.int32(38), np.int32(38), np.int32(38), np.int32(38), np.int32(39), np.int32(40), np.int32(40), np.int32(40), np.int32(40), np.int32(41), np.int32(41), np.int32(41), np.int32(41), np.int32(41), np.int32(42), np.int32(43), np.int32(43), np.int32(43), np.int32(43), np.int32(43), np.int32(43), np.int32(43), np.int32(43), np.int32(43), np.int32(44), np.int32(44), np.int32(44), np.int32(45), np.int32(45), np.int32(45), np.int32(45), np.int32(45), np.int32(45), np.int32(46), np.int32(46), np.int32(47), np.int32(47), np.int32(47), np.int32(47), np.int32(47), np.int32(48), np.int32(48), np.int32(48), np.int32(48), np.int32(48), np.int32(48), np.int32(49), np.int32(49), np.int32(49), np.int32(49), np.int32(50), np.int32(50), np.int32(50), np.int32(50), np.int32(50), np.int32(50), np.int32(50), np.int32(50), np.int32(50), np.int32(50), np.int32(50), np.int32(51), np.int32(51), np.int32(51), np.int32(51), np.int32(51), np.int32(51), np.int32(52), np.int32(52), np.int32(52), np.int32(52), np.int32(52), np.int32(52), np.int32(52), np.int32(52), np.int32(52), np.int32(53), np.int32(53), np.int32(54), np.int32(54), np.int32(54), np.int32(54), np.int32(54), np.int32(54), np.int32(55), np.int32(55), np.int32(55), np.int32(55), np.int32(55), np.int32(55), np.int32(55), np.int32(55), np.int32(55), np.int32(56), np.int32(56), np.int32(56), np.int32(56), np.int32(56), np.int32(56), np.int32(57), np.int32(57), np.int32(57), np.int32(57), np.int32(58), np.int32(58), np.int32(58), np.int32(58), np.int32(58), np.int32(58), np.int ...

# %% [markdown]
# ## Insertion sort  (  O(n**2) )

# %%
def insertion_sort1(vetor):
    n = len(vetor)
    
    for i in range(1, n):
        marcado = vetor[i]
        
        j = i - 1
        while j >= 0 and marcado < vetor[j]:
            vetor[j + 1] = vetor[j]
            j -= 1
        vetor[j + 1] = marcado
    
    return vetor

# %%
def insertion_sort2(vetor):
    # Percorre cada elemento de L
    for i in range(1, len(vetor)):
        k = i
        # Insere o pivô na posição correta
        while k > 0 and vetor[k] < vetor[k-1]:
            vetor[k], vetor[k-1] = vetor[k-1], vetor[k]
            k = k - 1

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit insertion_sort1(vet)
# Out:
# 1.31 ms ± 4.84 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Vetor ordenado
print(vet)

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit insertion_sort2(vet)
# Out:
# 1.01 ms ± 26.2 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Shell sort  (  O(n**2)  - O(n log n) )

# %%
# shell sort
def shell_sort1(vetor):
    n = len(vetor)
    h = 1
    while h > 0:
        for i in range(h, n):
            c = vetor[i]
            j = i
            while j >= h and c < vetor[j - h]:
                vetor[j] = vetor[j - h]
                j = j - h
                vetor[j] = c
        h = int(h / 2.2)
    return vetor

# %%
def shell_sort2(vetor):
  intervalo = len(vetor) // 2

  while intervalo > 0:
    for i in range(intervalo, len(vetor)):
      temp = vetor[i]
      j = i
      while j >= intervalo and vetor[j - intervalo] > temp:
        vetor[j] = vetor[j - intervalo]
        j -= intervalo
      vetor[j] = temp
    intervalo //= 2

  return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit shell_sort1(vet)
# Out:
# 930 μs ± 9.56 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit shell_sort2(vet)
# Out:
# 12.2 ms ± 209 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Quick sort  (  O(n log n)  mas existem casos O(n**2)  )

# %%
def particao(vetor, inicio, final):
    pivo = vetor[final]
    i = inicio - 1

    for j in range(inicio, final):
        if vetor[j] <= pivo:
            i += 1
            vetor[i], vetor[j] = vetor[j], vetor[i]
        vetor[i + 1], vetor[final] = vetor[final], vetor[i + 1]
    return i + 1

def quick_sort(vetor, inicio=0, final=(len(vetor)-1)):
    if inicio < final:
        posicao = particao(vetor, inicio, final)
        # Esquerda
        quick_sort(vetor, inicio, posicao - 1)
        # Direito
        quick_sort(vetor, posicao + 1, final)
    return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit quick_sort(vet)
# Out:
# 862 ms ± 67.9 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Merge sort  ( O(n log n) )

# %%
# merge sort
def merge_sort(vetor):
    if len(vetor) > 1:
        divisao = len(vetor) // 2
        esquerda = vetor[:divisao].copy()
        direita = vetor[divisao:].copy()

        merge_sort(esquerda)
        merge_sort(direita)

        i, j, k = 0, 0, 0

        # Ordena esquerda e direita
        while i < len(esquerda) and j < len(direita):
            if esquerda[i] < direita[j]:
                vetor[k] = esquerda[i]
                i += 1
            else:
                vetor[k] = direita[j]
                j += 1
            k += 1

        # Ordenação final
        while i < len(esquerda):
            vetor[k] = esquerda[i]
            i += 1
            k += 1
        while j < len(direita):
            vetor[k] = direita[j]
            j += 1
            k += 1
    return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit merge_sort(vet)
# Out:
# 24.6 ms ± 600 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Comparativo entre algoritmos

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
type(vet)
# Out:
# list

# %%
vet = np.array(vet)
type(vet)
# Out:
# numpy.ndarray

# %%
len(vet)
# Out:
# 5000

# %%
# %timeit bubble_sort(vet.copy())
# Out:
# 10.2 s ± 29.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit selection_sort(vet.copy())
# Out:
# 4.73 s ± 179 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit insertion_sort2(vet.copy())
# Out:
# 7.93 s ± 67.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit shell_sort1(vet.copy())
# Out:
# 5.63 s ± 34.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit quick_sort(vet.copy(), 0, len(vetor) - 1)
# Out:
# 113 ms ± 1.69 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit merge_sort(vet.copy())
# Out:
# 74.5 ms ± 611 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## Fim das Aulas 11 e 12
